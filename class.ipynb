# %%
#задание первое

import requests
import json

def MaxValue():
    maxValue_ = 0
    maxName = ''
    courses = requests.get('https://www.cbr-xml-daily.ru/daily_json.js').json()
    for name, fullinf in courses['Valute'].items():
        courseValue = fullinf['Value']
        if courseValue > maxValue_:
            maxValue_ = courseValue
            maxName = fullinf['Name']
    return print(maxName)
        
MaxValue()
# Out:
# СДР (специальные права заимствования)

# %%
#задание второе

import requests
import json

class Rate:
    def __init__(self, format_ = 'value', diff = True):
        self.format = format_
        self.diff = diff
        
    def exchange_rates(self):
        """
        Возвращает ответ сервиса с информацией о валютах в виде:
        
        {
            'AMD': {
                'CharCode': 'AMD',
                'ID': 'R01060',
                'Name': 'Армянских драмов',
                'Nominal': 100,
                'NumCode': '051',
                'Previous': 14.103,
                'Value': 14.0879
                },
            ...
        }
        """
        self.r = requests.get('https://www.cbr-xml-daily.ru/daily_json.js')
        
        return self.r.json()['Valute']
    
    def make_format(self, currency):
        response = self.exchange_rates()
        if currency in response:
            if self.format == 'value' and self.diff == False:
                return response[currency]['Value']
            elif self.format == 'value' and self.diff == True:
                return response[currency]['Value'] - response[currency]['Previous']
        return
    
    def eur(self):
        return self.make_format('EUR')
    def usd(self):
        return self.make_format('USD')
    def brl(self):
        return self.make_format('BRL')
    
    def changes(self):
        req = requests.get('https://www.cbr-xml-daily.ru/daily_json.js').json()['Valute']
        for name_ in req:
            print(name_)
            print(self.make_format(name_))
        return 

r = Rate() 
r.changes() #при diff=True и без format=full возвращает изменение по сравнению с прошлым значением
# Out:
# AUD
# -0.2644999999999982
# AZN
# -0.9091999999999985
# GBP
# -1.5790999999999968
# AMD
# -0.3326999999999991
# BYN
# -0.2667999999999999
# BGN
# -0.632799999999996
# BRL
# -0.07840000000000025
# HUF
# 0.0376999999999974
# HKD
# -0.20420000000000016
# DKK
# -0.1639999999999997
# USD
# -1.544700000000006
# EUR
# -1.2218000000000018
# INR
# -0.20620000000000083
# KZT
# -0.32509999999999906
# CAD
# -0.8537999999999997
# KGS
# -4.26700000000001
# CNY
# -0.1477000000000004
# MDL
# -1.033699999999996
# NOK
# 0.42549999999999955
# PLN
# 0.037000000000002586
# RON
# -0.24429999999999907
# XDR
# -1.8888000000000034
# SGD
# -0.8790000000000049
# TJS
# -8.258600000000001
# TRY
# -1.926000000000002
# TMT
# -0.44200000000000017
# UZS
# -1.4472999999999985
# UAH
# -0.3683000000000014
# CZK
# -0.158299999999997
# SEK
# -0.5065999999999917
# CHF
# -1.0074999999999932
# ZAR
# -0.2354999999999947
# KRW
# -0.8714999999999975
# JPY
# -1.2826999999999913

# %%
#задание третье

class Employee:
    def __init__(self, name, seniority):
        self.name = name
        self.seniority = seniority
        
        self.grade = 1
    
    def grade_up(self):
        """Повышает уровень сотрудника"""
        self.grade += 1
    
    def publish_grade(self):
        """Публикация результатов аккредитации сотрудников"""
        print(self.name, self.grade)
    
    def check_if_it_is_time_for_upgrade(self):
        pass

# %%
class Designer(Employee):
    def __init__(self, name, seniority, awards = 2):
        super().__init__(name, seniority)
        self.awards = awards
        
    def check_if_it_is_time_for_upgrade(self):
        self.seniority += 1 + self.awards
        if self.seniority % 7 == 0:
            self.grade_up()
        
        return self.publish_grade()

# %%
Vasya = Designer('Василий', 2)

# %%
for i in range(22):
    Vasya.check_if_it_is_time_for_upgrade()
# Out:
# Василий 1
# Василий 1
# Василий 1
# Василий 2
# Василий 2
# Василий 2
# Василий 2
# Василий 2
# Василий 2
# Василий 2
# Василий 3
# Василий 3
# Василий 3
# Василий 3
# Василий 3
# Василий 3
# Василий 3
# Василий 4
# Василий 4
# Василий 4
# Василий 4
# Василий 4
